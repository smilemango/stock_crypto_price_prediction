# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime

# %%
data = pd.read_csv('dataset/eth.csv')
data.head()
# Out:
#         Date    Open    High     Low   Close          Volume  \
# 0  31.Oct.17  307.38  310.55  305.88  305.88  369,583,008.00
# 1   1.Nov.17  305.76  306.40  290.58  291.69  553,864,000.00
# 2   2.Nov.17  290.73  293.91  281.17  287.43  904,900,992.00
# 3   3.Nov.17  288.50  308.31  287.69  305.71  646,339,968.00
# 4   4.Nov.17  305.48  305.48  295.80  300.47  416,479,008.00
#
#           Market Cap
# 0  29,331,517,440.00
# 1  29,183,592,448.00
# 2  27,754,237,952.00
# 3  27,547,410,432.00
# 4  29,175,347,200.00

# %%
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2

# %%
seq_len = 50
sequence_length = seq_len + 1

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])

# %%
result[0]
# Out:
# array([308.215, 298.49 , 287.54 , 298.   , 300.64 , 298.245, 299.57 ,
#        297.805, 305.9  , 318.255, 309.63 , 308.82 , 308.83 , 317.72 ,
#        328.47 , 335.36 , 329.885, 331.24 , 338.655, 358.015, 362.715,
#        361.58 , 370.785, 400.82 , 441.865, 473.12 , 462.165, 480.94 ,
#        474.415, 473.69 , 433.37 , 450.46 , 466.445, 467.33 , 464.045,
#        465.61 , 441.46 , 427.905, 444.215, 480.2  , 451.15 , 478.035,
#        580.905, 672.895, 709.055, 659.095, 699.59 , 716.035, 746.58 ,
#        833.64 , 800.53 ])

# %%
result[1]
# Out:
# array([298.49 , 287.54 , 298.   , 300.64 , 298.245, 299.57 , 297.805,
#        305.9  , 318.255, 309.63 , 308.82 , 308.83 , 317.72 , 328.47 ,
#        335.36 , 329.885, 331.24 , 338.655, 358.015, 362.715, 361.58 ,
#        370.785, 400.82 , 441.865, 473.12 , 462.165, 480.94 , 474.415,
#        473.69 , 433.37 , 450.46 , 466.445, 467.33 , 464.045, 465.61 ,
#        441.46 , 427.905, 444.215, 480.2  , 451.15 , 478.035, 580.905,
#        672.895, 709.055, 659.095, 699.59 , 716.035, 746.58 , 833.64 ,
#        800.53 , 836.615])

# %%
def normalize_windows(data):
    normalized_data = []
    for window in data:
        normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalized_data.append(normalized_window)
    return np.array(normalized_data)

result = normalize_windows(result)

# split train and test data
row = int(round(result.shape[0] * 0.9))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :-1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1]

x_test = result[row:, :-1]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1]

x_train.shape, x_test.shape
# Out:
# ((283, 50, 1), (31, 50, 1))

# %%
data.shape
# Out:
# (365, 7)

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1)))

model.add(LSTM(64, return_sequences=False))

model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='rmsprop')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 39,905
# Trainable params: 39,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = datetime.datetime.now().strftime('%Y_%m_%d_%H_%M_%S')

model.fit(x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=10,
    epochs=200,
    callbacks=[
        TensorBoard(log_dir='logs/%s' % (start_time)),
        ModelCheckpoint('./models/%s_eth.h5' % (start_time), monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, mode='auto')
])
# Out:
# Epoch 1/200
# 29/29 [==============================] - 9s 130ms/step - loss: 0.2132 - val_loss: 0.0013
#
# Epoch 00001: val_loss improved from inf to 0.00131, saving model to ./models/2021_03_01_22_30_47_eth.h5
# Epoch 2/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0514 - val_loss: 0.0017
#
# Epoch 00002: val_loss did not improve from 0.00131
# Epoch 3/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0512 - val_loss: 0.0013
#
# Epoch 00003: val_loss improved from 0.00131 to 0.00125, saving model to ./models/2021_03_01_22_30_47_eth.h5
# Epoch 4/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0272 - val_loss: 0.0011
#
# Epoch 00004: val_loss improved from 0.00125 to 0.00113, saving model to ./models/2021_03_01_22_30_47_eth.h5
# Epoch 5/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0315 - val_loss: 0.0022
#
# Epoch 00005: val_loss did not improve from 0.00113
# Epoch 6/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0291 - val_loss: 0.0022
#
# Epoch 00006: val_loss did not improve from 0.00113
# Epoch 7/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0244 - val_loss: 9.6519e-04
#
# Epoch 00007: val_loss improved from 0.00113 to 0.00097, saving model to ./models/2021_03_01_22_30_47_eth.h5
# Epoch 8/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0190 - val_loss: 0.0015
#
# Epoch 00008: val_loss did not improve from 0.00097
# Epoch 9/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0147 - val_loss: 0.0035
#
# Epoch 00009: val_loss did not improve from 0.00097
# Epoch 10/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0193 - val_loss: 8.1769e-04
#
# Epoch 00010: val_loss improved from 0.00097 to 0.00082, saving model to ./models/2021_03_01_22_30_47_eth.h5
# Epoch 11/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0147 - val_loss: 0.0013
#
# Epoch 00011: val_loss did not improve from 0.00082
# Epoch 12/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0159 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00082
# Epoch 13/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0140 - val_loss: 0.0034
#
# Epoch 00013: val_loss did not improve from 0.00082
# Epoch 14/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0116 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00082
# Epoch 15/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0175 - val_loss: 7.5258e-04
#
# Epoch 00015: val_loss improved from 0.00082 to 0.00075, saving model to ./models/2021_03_01_22_30_47_eth.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0094 - val_loss: 9.9109e-04
#
# Epoch 00016: val_loss did not improve from 0.00075
# Epoch 17/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0120 - val_loss: 8.4426e-04
#
# Epoch 00017: val_loss did not improve from 0.00075
# Epoch 18/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0115 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00075
# Epoch 19/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0116 - val_loss: 8.1636e-04
#
# Epoch 00019: val_loss did not improve from 0.00075
# Epoch 20/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0087 - val_loss: 7.6477e-04
#
# Epoch 00020: val_loss did not improve from 0.00075
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 21/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0113 - val_loss: 8.4026e-04
#
# Epoch 00021: val_loss did not improve from 0.00075
# Epoch 22/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0125 - val_loss: 8.7845e-04
#
# Epoch 00022: val_loss did not improve from 0.00075
# Epoch 23/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0115 - val_loss: 8.6446e-04
#
# Epoch 00023: val_loss did not improve from 0.00075
# Epoch 24/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0106 - val_loss: 8.8460e-04
#
# Epoch 00024: val_loss did not improve from 0.00075
# Epoch 25/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0086 - val_loss: 8.8375e-04
#
# Epoch 00025: val_loss did not improve from 0.00075
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 26/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0084 - val_loss: 8.7779e-04
#
# Epoch 00026: val_loss did not improve from 0.00075
# Epoch 27/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0119 - val_loss: 8.7303e-04
#
# Epoch 00027: val_loss did not improve from 0.00075
# Epoch 28/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0099 - val_loss: 8.7064e-04
#
# Epoch 00028: val_loss did not improve from 0.00075
# Epoch 29/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0092 - val_loss: 8.7545e-04
#
# Epoch 00029: val_loss did not improve from 0.00075
# Epoch 30/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0107 - val_loss: 8.8171e-04
#
# Epoch 00030: val_loss did not improve from 0.00075
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 31/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0111 - val_loss: 8.8204e-04
#
# Epoch 00031: val_loss did not improve from 0.00075
# Epoch 32/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8203e-04
#
# Epoch 00032: val_loss did not improve from 0.00075
# Epoch 33/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0086 - val_loss: 8.8302e-04
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0107 - val_loss: 8.8128e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0102 - val_loss: 8.8079e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 36/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0118 - val_loss: 8.8095e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0101 - val_loss: 8.8102e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0089 - val_loss: 8.8076e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0110 - val_loss: 8.8076e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0085 - val_loss: 8.8118e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 41/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0083 - val_loss: 8.8116e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0085 - val_loss: 8.8112e-04
#
# Epoch 00042: val_loss did not improve from 0.00075
# Epoch 43/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0090 - val_loss: 8.8115e-04
#
# Epoch 00043: val_loss did not improve from 0.00075
# Epoch 44/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0079 - val_loss: 8.8116e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 46/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0107 - val_loss: 8.8114e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0084 - val_loss: 8.8113e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0121 - val_loss: 8.8113e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 51/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0088 - val_loss: 8.8113e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0123 - val_loss: 8.8113e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0084 - val_loss: 8.8113e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0117 - val_loss: 8.8113e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 56/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0085 - val_loss: 8.8113e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 61/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0103 - val_loss: 8.8113e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0111 - val_loss: 8.8113e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0080 - val_loss: 8.8113e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0085 - val_loss: 8.8113e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 66/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0085 - val_loss: 8.8113e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0097 - val_loss: 8.8113e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 71/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0082 - val_loss: 8.8113e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0083 - val_loss: 8.8113e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0103 - val_loss: 8.8113e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0107 - val_loss: 8.8113e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0132 - val_loss: 8.8113e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 76/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0078 - val_loss: 8.8113e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0115 - val_loss: 8.8113e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0099 - val_loss: 8.8113e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 81/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0076 - val_loss: 8.8113e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0075 - val_loss: 8.8113e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0088 - val_loss: 8.8113e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0088 - val_loss: 8.8113e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0069 - val_loss: 8.8113e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 86/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0105 - val_loss: 8.8113e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0080 - val_loss: 8.8113e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0106 - val_loss: 8.8113e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0081 - val_loss: 8.8113e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# Epoch 91/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0142 - val_loss: 8.8113e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0086 - val_loss: 8.8113e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# Epoch 96/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0097 - val_loss: 8.8113e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0092 - val_loss: 8.8113e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0097 - val_loss: 8.8113e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0085 - val_loss: 8.8113e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0074 - val_loss: 8.8113e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 2.6214401285682084e-16.
# Epoch 101/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0088 - val_loss: 8.8113e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0083 - val_loss: 8.8113e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0109 - val_loss: 8.8113e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 5.2428803630155353e-17.
# Epoch 106/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0121 - val_loss: 8.8113e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0120 - val_loss: 8.8113e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/200
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 1.0485760990728867e-17.
# Epoch 111/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0097 - val_loss: 8.8113e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0084 - val_loss: 8.8113e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0071 - val_loss: 8.8113e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0083 - val_loss: 8.8113e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0077 - val_loss: 8.8113e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 2.097152165058549e-18.
# Epoch 116/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0083 - val_loss: 8.8113e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0115 - val_loss: 8.8113e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0107 - val_loss: 8.8113e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 4.19430449555322e-19.
# Epoch 121/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0106 - val_loss: 8.8113e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0106 - val_loss: 8.8113e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0104 - val_loss: 8.8113e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0101 - val_loss: 8.8113e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 8.388609197901593e-20.
# Epoch 126/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0136 - val_loss: 8.8113e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0099 - val_loss: 8.8113e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 1.6777218395803187e-20.
# Epoch 131/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0104 - val_loss: 8.8113e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 3.3554436145371517e-21.
# Epoch 136/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0118 - val_loss: 8.8113e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/200
# 29/29 [==============================] - 1s 52ms/step - loss: 0.0138 - val_loss: 8.8113e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
#
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 6.710887229074304e-22.
# Epoch 141/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0108 - val_loss: 8.8113e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0076 - val_loss: 8.8113e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0102 - val_loss: 8.8113e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0085 - val_loss: 8.8113e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0093 - val_loss: 8.8113e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 1.3421774862045392e-22.
# Epoch 146/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0093 - val_loss: 8.8113e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0145 - val_loss: 8.8113e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0079 - val_loss: 8.8113e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0089 - val_loss: 8.8113e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0094 - val_loss: 8.8113e-04
#
# Epoch 00150: val_loss did not improve from 0.00075
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 2.684355073383274e-23.
# Epoch 151/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0097 - val_loss: 8.8113e-04
#
# Epoch 00151: val_loss did not improve from 0.00075
# Epoch 152/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00152: val_loss did not improve from 0.00075
# Epoch 153/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0101 - val_loss: 8.8113e-04
#
# Epoch 00153: val_loss did not improve from 0.00075
# Epoch 154/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0126 - val_loss: 8.8113e-04
#
# Epoch 00154: val_loss did not improve from 0.00075
# Epoch 155/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0084 - val_loss: 8.8113e-04
#
# Epoch 00155: val_loss did not improve from 0.00075
#
# Epoch 00155: ReduceLROnPlateau reducing learning rate to 5.368710272984293e-24.
# Epoch 156/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0108 - val_loss: 8.8113e-04
#
# Epoch 00156: val_loss did not improve from 0.00075
# Epoch 157/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0093 - val_loss: 8.8113e-04
#
# Epoch 00157: val_loss did not improve from 0.00075
# Epoch 158/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00158: val_loss did not improve from 0.00075
# Epoch 159/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00159: val_loss did not improve from 0.00075
# Epoch 160/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00160: val_loss did not improve from 0.00075
#
# Epoch 00160: ReduceLROnPlateau reducing learning rate to 1.0737420861512948e-24.
# Epoch 161/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0087 - val_loss: 8.8113e-04
#
# Epoch 00161: val_loss did not improve from 0.00075
# Epoch 162/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0104 - val_loss: 8.8113e-04
#
# Epoch 00162: val_loss did not improve from 0.00075
# Epoch 163/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0107 - val_loss: 8.8113e-04
#
# Epoch 00163: val_loss did not improve from 0.00075
# Epoch 164/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0111 - val_loss: 8.8113e-04
#
# Epoch 00164: val_loss did not improve from 0.00075
# Epoch 165/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0091 - val_loss: 8.8113e-04
#
# Epoch 00165: val_loss did not improve from 0.00075
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 2.147484093416499e-25.
# Epoch 166/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00166: val_loss did not improve from 0.00075
# Epoch 167/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0078 - val_loss: 8.8113e-04
#
# Epoch 00167: val_loss did not improve from 0.00075
# Epoch 168/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0086 - val_loss: 8.8113e-04
#
# Epoch 00168: val_loss did not improve from 0.00075
# Epoch 169/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0090 - val_loss: 8.8113e-04
#
# Epoch 00169: val_loss did not improve from 0.00075
# Epoch 170/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0127 - val_loss: 8.8113e-04
#
# Epoch 00170: val_loss did not improve from 0.00075
#
# Epoch 00170: ReduceLROnPlateau reducing learning rate to 4.2949679896177717e-26.
# Epoch 171/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0078 - val_loss: 8.8113e-04
#
# Epoch 00171: val_loss did not improve from 0.00075
# Epoch 172/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0125 - val_loss: 8.8113e-04
#
# Epoch 00172: val_loss did not improve from 0.00075
# Epoch 173/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0093 - val_loss: 8.8113e-04
#
# Epoch 00173: val_loss did not improve from 0.00075
# Epoch 174/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0082 - val_loss: 8.8113e-04
#
# Epoch 00174: val_loss did not improve from 0.00075
# Epoch 175/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0099 - val_loss: 8.8113e-04
#
# Epoch 00175: val_loss did not improve from 0.00075
#
# Epoch 00175: ReduceLROnPlateau reducing learning rate to 8.589935979235544e-27.
# Epoch 176/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0092 - val_loss: 8.8113e-04
#
# Epoch 00176: val_loss did not improve from 0.00075
# Epoch 177/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0103 - val_loss: 8.8113e-04
#
# Epoch 00177: val_loss did not improve from 0.00075
# Epoch 178/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0092 - val_loss: 8.8113e-04
#
# Epoch 00178: val_loss did not improve from 0.00075
# Epoch 179/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00179: val_loss did not improve from 0.00075
# Epoch 180/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00180: val_loss did not improve from 0.00075
#
# Epoch 00180: ReduceLROnPlateau reducing learning rate to 1.7179871342173507e-27.
# Epoch 181/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0057 - val_loss: 8.8113e-04
#
# Epoch 00181: val_loss did not improve from 0.00075
# Epoch 182/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0102 - val_loss: 8.8113e-04
#
# Epoch 00182: val_loss did not improve from 0.00075
# Epoch 183/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0083 - val_loss: 8.8113e-04
#
# Epoch 00183: val_loss did not improve from 0.00075
# Epoch 184/200
# 29/29 [==============================] - 1s 52ms/step - loss: 0.0080 - val_loss: 8.8113e-04
#
# Epoch 00184: val_loss did not improve from 0.00075
# Epoch 185/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0101 - val_loss: 8.8113e-04
#
# Epoch 00185: val_loss did not improve from 0.00075
#
# Epoch 00185: ReduceLROnPlateau reducing learning rate to 3.435974191397503e-28.
# Epoch 186/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00186: val_loss did not improve from 0.00075
# Epoch 187/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0086 - val_loss: 8.8113e-04
#
# Epoch 00187: val_loss did not improve from 0.00075
# Epoch 188/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0104 - val_loss: 8.8113e-04
#
# Epoch 00188: val_loss did not improve from 0.00075
# Epoch 189/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00189: val_loss did not improve from 0.00075
# Epoch 190/200
# 29/29 [==============================] - 1s 52ms/step - loss: 0.0100 - val_loss: 8.8113e-04
#
# Epoch 00190: val_loss did not improve from 0.00075
#
# Epoch 00190: ReduceLROnPlateau reducing learning rate to 6.871948190202012e-29.
# Epoch 191/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0077 - val_loss: 8.8113e-04
#
# Epoch 00191: val_loss did not improve from 0.00075
# Epoch 192/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0099 - val_loss: 8.8113e-04
#
# Epoch 00192: val_loss did not improve from 0.00075
# Epoch 193/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0098 - val_loss: 8.8113e-04
#
# Epoch 00193: val_loss did not improve from 0.00075
# Epoch 194/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0105 - val_loss: 8.8113e-04
#
# Epoch 00194: val_loss did not improve from 0.00075
# Epoch 195/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0102 - val_loss: 8.8113e-04
#
# Epoch 00195: val_loss did not improve from 0.00075
#
# Epoch 00195: ReduceLROnPlateau reducing learning rate to 1.3743895898921537e-29.
# Epoch 196/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0116 - val_loss: 8.8113e-04
#
# Epoch 00196: val_loss did not improve from 0.00075
# Epoch 197/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0088 - val_loss: 8.8113e-04
#
# Epoch 00197: val_loss did not improve from 0.00075
# Epoch 198/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0108 - val_loss: 8.8113e-04
#
# Epoch 00198: val_loss did not improve from 0.00075
# Epoch 199/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0096 - val_loss: 8.8113e-04
#
# Epoch 00199: val_loss did not improve from 0.00075
# Epoch 200/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0093 - val_loss: 8.8113e-04
#
# Epoch 00200: val_loss did not improve from 0.00075
#
# Epoch 00200: ReduceLROnPlateau reducing learning rate to 2.7487793001549293e-30.

# %%
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend()
plt.show()
